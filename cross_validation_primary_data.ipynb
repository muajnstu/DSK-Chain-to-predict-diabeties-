# %% [markdown]
# <a href="https://colab.research.google.com/github/muajnstu/Comparative-Analysis-of-KNN-Variants-for-Diabetes-Prediction-Using-Administrative-Health-data/blob/main/cross_validation_primary_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.11/dist-packages (from imblearn) (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn->imblearn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn->imblearn) (1.16.0)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn->imblearn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn->imblearn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn->imblearn) (3.6.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_auc_score
from sklearn.preprocessing import label_binarize
from imblearn.over_sampling import SMOTE

# %%
# Load data
df = pd.read_csv('https://raw.githubusercontent.com/muajnstu/Comparative-Analysis-of-K-Nearest-Neighbors-Variants-for-Diabetes-Prediction-Using-Administrative-He/refs/heads/main/raw%20data.csv')
X = df.drop(columns=['Outcome'])
y = df['Outcome']

# %%
# KNN variant definitions
def get_knn_variants(X_train):
    covariance_matrix = np.cov(X_train.T)
    stabilized_covariance_matrix = covariance_matrix + np.eye(covariance_matrix.shape[0]) * 1e-6
    inv_covariance_matrix = np.linalg.inv(stabilized_covariance_matrix)
    variance_vector = np.var(X_train, axis=0)
    knn_variants = {
        "KNN": KNeighborsClassifier(n_neighbors=3),
        "DistanceKNN": KNeighborsClassifier(n_neighbors=3, weights='distance'),
        "GeneralizedKNN": KNeighborsClassifier(n_neighbors=3, metric='minkowski', p=3),
        "EuclideanKNN": KNeighborsClassifier(n_neighbors=3, metric='euclidean'),
        "ManhattanKNN": KNeighborsClassifier(n_neighbors=3, metric='manhattan'),
        "ChebyshevKNN": KNeighborsClassifier(n_neighbors=3, metric='chebyshev'),
        "MahalanobisKNN": KNeighborsClassifier(n_neighbors=3, metric='mahalanobis', metric_params={'VI': inv_covariance_matrix}),
        "SeuclideanKNN": KNeighborsClassifier(n_neighbors=3, metric='seuclidean', metric_params={'V': variance_vector}),
        "WminkowskiKNN": KNeighborsClassifier(n_neighbors=3, metric='minkowski', p=3, metric_params={'w': np.ones(X_train.shape[1])}),
    }
    return knn_variants

# %%
def print_metrics(y_true, y_pred, y_prob=None):
    cm = confusion_matrix(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)

    num_classes = cm.shape[0]

    if num_classes == 2:
        # Binary classification
        TN, FP, FN, TP = cm.ravel()
        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
        gmean = np.sqrt(specificity * sensitivity)
        type1 = FP / (FP + TN) if (FP + TN) > 0 else 0
        type2 = FN / (TP + FN) if (TP + FN) > 0 else 0
        fmeasure = f1_score(y_true, y_pred, pos_label=1)
        auc = 0
        if y_prob is not None and hasattr(y_prob, "shape") and y_prob.shape[1] > 1:
            try:
                auc = roc_auc_score(y_true, y_prob[:, 1])
            except Exception:
                auc = 0

    else:
        # Multiclass classification
        TP = np.diag(cm)
        FP = np.sum(cm, axis=0) - TP
        FN = np.sum(cm, axis=1) - TP
        TN = np.sum(cm) - (FP + FN + TP)

        specificity = np.mean([
            TN[i] / (TN[i] + FP[i]) if (TN[i] + FP[i]) > 0 else 0 for i in range(num_classes)
        ])
        sensitivity = np.mean([
            TP[i] / (TP[i] + FN[i]) if (TP[i] + FN[i]) > 0 else 0 for i in range(num_classes)
        ])
        gmean = np.sqrt(specificity * sensitivity)
        type1 = np.mean([
            FP[i] / (FP[i] + TN[i]) if (FP[i] + TN[i]) > 0 else 0 for i in range(num_classes)
        ])
        type2 = np.mean([
            FN[i] / (TP[i] + FN[i]) if (TP[i] + FN[i]) > 0 else 0 for i in range(num_classes)
        ])
        fmeasure = f1_score(y_true, y_pred, average='macro')

        auc = 0
        if y_prob is not None and hasattr(y_prob, "shape") and y_prob.shape[1] > 1:
            try:
                auc = roc_auc_score(y_true, y_prob, multi_class='ovr', average='macro')
            except Exception:
                auc = 0

    metrics = {
        "Accuracy": accuracy,
        "Sensitivity": sensitivity,
        "Specificity": specificity,
        "G-Mean": gmean,
        "Type I Error": type1,
        "Type II Error": type2,
        "F1 Score": fmeasure,
        "AUROC": auc
    }

    return metrics

# %%
all_results = []
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
knn_variants = get_knn_variants(X)

for name, model_proto in knn_variants.items():
    model_results = []
    print(f"\n==== {name} ====")

    for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
        X_train_cv, X_test_cv = X.iloc[train_idx], X.iloc[test_idx]
        y_train_cv, y_test_cv = y.iloc[train_idx], y.iloc[test_idx]

        # Handle special metric parameters
        if name == "MahalanobisKNN":
            covariance_matrix = np.cov(X_train_cv.T)
            stabilized_cov_matrix = covariance_matrix + np.eye(covariance_matrix.shape[0]) * 1e-6
            inv_cov_matrix = np.linalg.inv(stabilized_cov_matrix)
            model = KNeighborsClassifier(n_neighbors=3, metric='mahalanobis', metric_params={'VI': inv_cov_matrix})
        elif name == "SeuclideanKNN":
            variance_vector = np.var(X_train_cv, axis=0)
            model = KNeighborsClassifier(n_neighbors=3, metric='seuclidean', metric_params={'V': variance_vector})
        elif name == "WminkowskiKNN":
            model = KNeighborsClassifier(n_neighbors=3, metric='minkowski', p=3, metric_params={'w': np.ones(X_train_cv.shape[1])})
        else:
            model = KNeighborsClassifier(**model_proto.get_params())

        model.fit(X_train_cv, y_train_cv)
        y_pred = model.predict(X_test_cv)
        y_prob = model.predict_proba(X_test_cv) if hasattr(model, "predict_proba") else None

        metrics = print_metrics(y_test_cv, y_pred, y_prob)
        metrics["fold"] = fold + 1
        metrics["variant"] = name
        model_results.append(metrics)

        #  Only one fold-wise print
        print(f"Fold {fold+1}: " +
              ", ".join([f"{k}: {v:.4f}" for k, v in metrics.items() if k not in ["fold", "variant"]]))

    all_results.extend(model_results)
# Out:
# ==== KNN ====
# Fold 1: Accuracy: 0.7920, Sensitivity: 0.1256, Specificity: 0.9158, G-Mean: 0.3391, Type I Error: 0.0842, Type II Error: 0.8744, F1 Score: 0.1591, AUROC: 0.5425
# Fold 2: Accuracy: 0.7864, Sensitivity: 0.1659, Specificity: 0.9017, G-Mean: 0.3868, Type I Error: 0.0983, Type II Error: 0.8341, F1 Score: 0.1958, AUROC: 0.5981
# Fold 3: Accuracy: 0.7848, Sensitivity: 0.1937, Specificity: 0.8942, G-Mean: 0.4162, Type I Error: 0.1058, Type II Error: 0.8063, F1 Score: 0.2194, AUROC: 0.5795
# Fold 4: Accuracy: 0.7996, Sensitivity: 0.1441, Specificity: 0.9208, G-Mean: 0.3643, Type I Error: 0.0792, Type II Error: 0.8559, F1 Score: 0.1834, AUROC: 0.5735
# Fold 5: Accuracy: 0.7996, Sensitivity: 0.1982, Specificity: 0.9108, G-Mean: 0.4249, Type I Error: 0.0892, Type II Error: 0.8018, F1 Score: 0.2359, AUROC: 0.5868
# Fold 6: Accuracy: 0.8031, Sensitivity: 0.1351, Specificity: 0.9267, G-Mean: 0.3539, Type I Error: 0.0733, Type II Error: 0.8649, F1 Score: 0.1765, AUROC: 0.5525
# Fold 7: Accuracy: 0.8031, Sensitivity: 0.1306, Specificity: 0.9275, G-Mean: 0.3481, Type I Error: 0.0725, Type II Error: 0.8694, F1 Score: 0.1716, AUROC: 0.5470
# Fold 8: Accuracy: 0.8003, Sensitivity: 0.1667, Specificity: 0.9175, G-Mean: 0.3910, Type I Error: 0.0825, Type II Error: 0.8333, F1 Score: 0.2067, AUROC: 0.5705
# Fold 9: Accuracy: 0.8087, Sensitivity: 0.1351, Specificity: 0.9333, G-Mean: 0.3551, Type I Error: 0.0667, Type II Error: 0.8649, F1 Score: 0.1807, AUROC: 0.5678
# Fold 10: Accuracy: 0.7827, Sensitivity: 0.2297, Specificity: 0.8850, G-Mean: 0.4509, Type I Error: 0.1150, Type II Error: 0.7703, F1 Score: 0.2482, AUROC: 0.5931
#
# ==== DistanceKNN ====
# Fold 1: Accuracy: 0.7885, Sensitivity: 0.1300, Specificity: 0.9108, G-Mean: 0.3442, Type I Error: 0.0892, Type II Error: 0.8700, F1 Score: 0.1616, AUROC: 0.5476
# Fold 2: Accuracy: 0.7850, Sensitivity: 0.1839, Specificity: 0.8967, G-Mean: 0.4060, Type I Error: 0.1033, Type II Error: 0.8161, F1 Score: 0.2113, AUROC: 0.5936
# Fold 3: Accuracy: 0.7827, Sensitivity: 0.2072, Specificity: 0.8892, G-Mean: 0.4292, Type I Error: 0.1108, Type II Error: 0.7928, F1 Score: 0.2294, AUROC: 0.5877
# Fold 4: Accuracy: 0.7954, Sensitivity: 0.1622, Specificity: 0.9125, G-Mean: 0.3847, Type I Error: 0.0875, Type II Error: 0.8378, F1 Score: 0.1983, AUROC: 0.5660
# Fold 5: Accuracy: 0.7961, Sensitivity: 0.2072, Specificity: 0.9050, G-Mean: 0.4330, Type I Error: 0.0950, Type II Error: 0.7928, F1 Score: 0.2408, AUROC: 0.5887
# Fold 6: Accuracy: 0.7996, Sensitivity: 0.1396, Specificity: 0.9217, G-Mean: 0.3587, Type I Error: 0.0783, Type II Error: 0.8604, F1 Score: 0.1787, AUROC: 0.5492
# Fold 7: Accuracy: 0.7954, Sensitivity: 0.1306, Specificity: 0.9183, G-Mean: 0.3464, Type I Error: 0.0817, Type II Error: 0.8694, F1 Score: 0.1662, AUROC: 0.5449
# Fold 8: Accuracy: 0.7961, Sensitivity: 0.1667, Specificity: 0.9125, G-Mean: 0.3900, Type I Error: 0.0875, Type II Error: 0.8333, F1 Score: 0.2033, AUROC: 0.5666
# Fold 9: Accuracy: 0.8038, Sensitivity: 0.1441, Specificity: 0.9258, G-Mean: 0.3653, Type I Error: 0.0742, Type II Error: 0.8559, F1 Score: 0.1866, AUROC: 0.5693
# Fold 10: Accuracy: 0.7883, Sensitivity: 0.2477, Specificity: 0.8883, G-Mean: 0.4691, Type I Error: 0.1117, Type II Error: 0.7523, F1 Score: 0.2676, AUROC: 0.5897
#
# ==== GeneralizedKNN ====
# Fold 1: Accuracy: 0.8067, Sensitivity: 0.1390, Specificity: 0.9308, G-Mean: 0.3597, Type I Error: 0.0692, Type II Error: 0.8610, F1 Score: 0.1840, AUROC: 0.5642
# Fold 2: Accuracy: 0.7941, Sensitivity: 0.1883, Specificity: 0.9067, G-Mean: 0.4132, Type I Error: 0.0933, Type II Error: 0.8117, F1 Score: 0.2228, AUROC: 0.5835
# Fold 3: Accuracy: 0.7982, Sensitivity: 0.1261, Specificity: 0.9225, G-Mean: 0.3411, Type I Error: 0.0775, Type II Error: 0.8739, F1 Score: 0.1633, AUROC: 0.5597
# Fold 4: Accuracy: 0.7982, Sensitivity: 0.1757, Specificity: 0.9133, G-Mean: 0.4006, Type I Error: 0.0867, Type II Error: 0.8243, F1 Score: 0.2137, AUROC: 0.5643
# Fold 5: Accuracy: 0.8003, Sensitivity: 0.1171, Specificity: 0.9267, G-Mean: 0.3294, Type I Error: 0.0733, Type II Error: 0.8829, F1 Score: 0.1548, AUROC: 0.5521
# Fold 6: Accuracy: 0.7940, Sensitivity: 0.1306, Specificity: 0.9167, G-Mean: 0.3460, Type I Error: 0.0833, Type II Error: 0.8694, F1 Score: 0.1652, AUROC: 0.5320
# Fold 7: Accuracy: 0.7876, Sensitivity: 0.1306, Specificity: 0.9092, G-Mean: 0.3446, Type I Error: 0.0908, Type II Error: 0.8694, F1 Score: 0.1611, AUROC: 0.5378
# Fold 8: Accuracy: 0.7989, Sensitivity: 0.1577, Specificity: 0.9175, G-Mean: 0.3803, Type I Error: 0.0825, Type II Error: 0.8423, F1 Score: 0.1966, AUROC: 0.6184
# Fold 9: Accuracy: 0.8150, Sensitivity: 0.1712, Specificity: 0.9342, G-Mean: 0.3999, Type I Error: 0.0658, Type II Error: 0.8288, F1 Score: 0.2242, AUROC: 0.5773
# Fold 10: Accuracy: 0.8136, Sensitivity: 0.1486, Specificity: 0.9367, G-Mean: 0.3731, Type I Error: 0.0633, Type II Error: 0.8514, F1 Score: 0.1994, AUROC: 0.5737
#
# ==== EuclideanKNN ====
# Fold 1: Accuracy: 0.7920, Sensitivity: 0.1256, Specificity: 0.9158, G-Mean: 0.3391, Type I Error: 0.0842, Type II Error: 0.8744, F1 Score: 0.1591, AUROC: 0.5425
# Fold 2: Accuracy: 0.7864, Sensitivity: 0.1659, Specificity: 0.9017, G-Mean: 0.3868, Type I Error: 0.0983, Type II Error: 0.8341, F1 Score: 0.1958, AUROC: 0.5981
# Fold 3: Accuracy: 0.7848, Sensitivity: 0.1937, Specificity: 0.8942, G-Mean: 0.4162, Type I Error: 0.1058, Type II Error: 0.8063, F1 Score: 0.2194, AUROC: 0.5795
# Fold 4: Accuracy: 0.7996, Sensitivity: 0.1441, Specificity: 0.9208, G-Mean: 0.3643, Type I Error: 0.0792, Type II Error: 0.8559, F1 Score: 0.1834, AUROC: 0.5735
# Fold 5: Accuracy: 0.7996, Sensitivity: 0.1982, Specificity: 0.9108, G-Mean: 0.4249, Type I Error: 0.0892, Type II Error: 0.8018, F1 Score: 0.2359, AUROC: 0.5868
# Fold 6: Accuracy: 0.8031, Sensitivity: 0.1351, Specificity: 0.9267, G-Mean: 0.3539, Type I Error: 0.0733, Type II Error: 0.8649, F1 Score: 0.1765, AUROC: 0.5525
# Fold 7: Accuracy: 0.8031, Sensitivity: 0.1306, Specificity: 0.9275, G-Mean: 0.3481, Type I Error: 0.0725, Type II Error: 0.8694, F1 Score: 0.1716, AUROC: 0.5470
# Fold 8: Accuracy: 0.8003, Sensitivity: 0.1667, Specificity: 0.9175, G-Mean: 0.3910, Type I Error: 0.0825, Type II Error: 0.8333, F1 Score: 0.2067, AUROC: 0.5705
# Fold 9: Accuracy: 0.8087, Sensitivity: 0.1351, Specificity: 0.9333, G-Mean: 0.3551, Type I Error: 0.0667, Type II Error: 0.8649, F1 Score: 0.1807, AUROC: 0.5678
# Fold 10: Accuracy: 0.7827, Sensitivity: 0.2297, Specificity: 0.8850, G-Mean: 0.4509, Type I Error: 0.1150, Type II Error: 0.7703, F1 Score: 0.2482, AUROC: 0.5931
#
# ==== ManhattanKNN ====
# Fold 1: Accuracy: 0.7934, Sensitivity: 0.1704, Specificity: 0.9092, G-Mean: 0.3936, Type I Error: 0.0908, Type II Error: 0.8296, F1 Score: 0.2054, AUROC: 0.5636
# Fold 2: Accuracy: 0.7920, Sensitivity: 0.2108, Specificity: 0.9000, G-Mean: 0.4355, Type I Error: 0.1000, Type II Error: 0.7892, F1 Score: 0.2410, AUROC: 0.6066
# Fold 3: Accuracy: 0.8136, Sensitivity: 0.1712, Specificity: 0.9325, G-Mean: 0.3995, Type I Error: 0.0675, Type II Error: 0.8288, F1 Score: 0.2229, AUROC: 0.5612
# Fold 4: Accuracy: 0.7918, Sensitivity: 0.1396, Specificity: 0.9125, G-Mean: 0.3570, Type I Error: 0.0875, Type II Error: 0.8604, F1 Score: 0.1732, AUROC: 0.5550
# Fold 5: Accuracy: 0.8087, Sensitivity: 0.1802, Specificity: 0.9250, G-Mean: 0.4082, Type I Error: 0.0750, Type II Error: 0.8198, F1 Score: 0.2273, AUROC: 0.5920
# Fold 6: Accuracy: 0.7925, Sensitivity: 0.1622, Specificity: 0.9092, G-Mean: 0.3840, Type I Error: 0.0908, Type II Error: 0.8378, F1 Score: 0.1962, AUROC: 0.5672
# Fold 7: Accuracy: 0.8045, Sensitivity: 0.1441, Specificity: 0.9267, G-Mean: 0.3655, Type I Error: 0.0733, Type II Error: 0.8559, F1 Score: 0.1871, AUROC: 0.5593
# Fold 8: Accuracy: 0.7940, Sensitivity: 0.1802, Specificity: 0.9075, G-Mean: 0.4044, Type I Error: 0.0925, Type II Error: 0.8198, F1 Score: 0.2145, AUROC: 0.5869
# Fold 9: Accuracy: 0.8024, Sensitivity: 0.1441, Specificity: 0.9242, G-Mean: 0.3650, Type I Error: 0.0758, Type II Error: 0.8559, F1 Score: 0.1855, AUROC: 0.5596
# Fold 10: Accuracy: 0.8172, Sensitivity: 0.1757, Specificity: 0.9358, G-Mean: 0.4055, Type I Error: 0.0642, Type II Error: 0.8243, F1 Score: 0.2308, AUROC: 0.6039
#
# ==== ChebyshevKNN ====
# Fold 1: Accuracy: 0.8067, Sensitivity: 0.1435, Specificity: 0.9300, G-Mean: 0.3653, Type I Error: 0.0700, Type II Error: 0.8565, F1 Score: 0.1888, AUROC: 0.5687
# Fold 2: Accuracy: 0.7456, Sensitivity: 0.2242, Specificity: 0.8425, G-Mean: 0.4346, Type I Error: 0.1575, Type II Error: 0.7758, F1 Score: 0.2165, AUROC: 0.5609
# Fold 3: Accuracy: 0.7954, Sensitivity: 0.1712, Specificity: 0.9108, G-Mean: 0.3949, Type I Error: 0.0892, Type II Error: 0.8288, F1 Score: 0.2071, AUROC: 0.5558
# Fold 4: Accuracy: 0.7736, Sensitivity: 0.1847, Specificity: 0.8825, G-Mean: 0.4037, Type I Error: 0.1175, Type II Error: 0.8153, F1 Score: 0.2030, AUROC: 0.5756
# Fold 5: Accuracy: 0.7848, Sensitivity: 0.1261, Specificity: 0.9067, G-Mean: 0.3382, Type I Error: 0.0933, Type II Error: 0.8739, F1 Score: 0.1547, AUROC: 0.5174
# Fold 6: Accuracy: 0.7778, Sensitivity: 0.1532, Specificity: 0.8933, G-Mean: 0.3699, Type I Error: 0.1067, Type II Error: 0.8468, F1 Score: 0.1771, AUROC: 0.5278
# Fold 7: Accuracy: 0.7806, Sensitivity: 0.1622, Specificity: 0.8950, G-Mean: 0.3810, Type I Error: 0.1050, Type II Error: 0.8378, F1 Score: 0.1875, AUROC: 0.5574
# Fold 8: Accuracy: 0.7975, Sensitivity: 0.1712, Specificity: 0.9133, G-Mean: 0.3954, Type I Error: 0.0867, Type II Error: 0.8288, F1 Score: 0.2088, AUROC: 0.5896
# Fold 9: Accuracy: 0.7940, Sensitivity: 0.1261, Specificity: 0.9175, G-Mean: 0.3402, Type I Error: 0.0825, Type II Error: 0.8739, F1 Score: 0.1605, AUROC: 0.5752
# Fold 10: Accuracy: 0.8024, Sensitivity: 0.1847, Specificity: 0.9167, G-Mean: 0.4115, Type I Error: 0.0833, Type II Error: 0.8153, F1 Score: 0.2259, AUROC: 0.6119
#
# ==== MahalanobisKNN ====
# Fold 1: Accuracy: 0.7976, Sensitivity: 0.1121, Specificity: 0.9250, G-Mean: 0.3220, Type I Error: 0.0750, Type II Error: 0.8879, F1 Score: 0.1479, AUROC: 0.5678
# Fold 2: Accuracy: 0.7920, Sensitivity: 0.1614, Specificity: 0.9092, G-Mean: 0.3831, Type I Error: 0.0908, Type II Error: 0.8386, F1 Score: 0.1957, AUROC: 0.5973
# Fold 3: Accuracy: 0.7989, Sensitivity: 0.2072, Specificity: 0.9083, G-Mean: 0.4338, Type I Error: 0.0917, Type II Error: 0.7928, F1 Score: 0.2434, AUROC: 0.6115
# Fold 4: Accuracy: 0.7806, Sensitivity: 0.1306, Specificity: 0.9008, G-Mean: 0.3430, Type I Error: 0.0992, Type II Error: 0.8694, F1 Score: 0.1568, AUROC: 0.5578
# Fold 5: Accuracy: 0.8115, Sensitivity: 0.1351, Specificity: 0.9367, G-Mean: 0.3558, Type I Error: 0.0633, Type II Error: 0.8649, F1 Score: 0.1829, AUROC: 0.5780
# Fold 6: Accuracy: 0.7925, Sensitivity: 0.1532, Specificity: 0.9108, G-Mean: 0.3735, Type I Error: 0.0892, Type II Error: 0.8468, F1 Score: 0.1873, AUROC: 0.5498
# Fold 7: Accuracy: 0.7961, Sensitivity: 0.1847, Specificity: 0.9092, G-Mean: 0.4098, Type I Error: 0.0908, Type II Error: 0.8153, F1 Score: 0.2204, AUROC: 0.5755
# Fold 8: Accuracy: 0.8101, Sensitivity: 0.1577, Specificity: 0.9308, G-Mean: 0.3831, Type I Error: 0.0692, Type II Error: 0.8423, F1 Score: 0.2059, AUROC: 0.6057
# Fold 9: Accuracy: 0.7911, Sensitivity: 0.1937, Specificity: 0.9017, G-Mean: 0.4179, Type I Error: 0.0983, Type II Error: 0.8063, F1 Score: 0.2245, AUROC: 0.5680
# Fold 10: Accuracy: 0.7961, Sensitivity: 0.1892, Specificity: 0.9083, G-Mean: 0.4145, Type I Error: 0.0917, Type II Error: 0.8108, F1 Score: 0.2246, AUROC: 0.5787
#
# ==== SeuclideanKNN ====
# Fold 1: Accuracy: 0.8053, Sensitivity: 0.1256, Specificity: 0.9317, G-Mean: 0.3420, Type I Error: 0.0683, Type II Error: 0.8744, F1 Score: 0.1682, AUROC: 0.5500
# Fold 2: Accuracy: 0.7850, Sensitivity: 0.1794, Specificity: 0.8975, G-Mean: 0.4012, Type I Error: 0.1025, Type II Error: 0.8206, F1 Score: 0.2073, AUROC: 0.5781
# Fold 3: Accuracy: 0.7799, Sensitivity: 0.1892, Specificity: 0.8892, G-Mean: 0.4101, Type I Error: 0.1108, Type II Error: 0.8108, F1 Score: 0.2116, AUROC: 0.5835
# Fold 4: Accuracy: 0.7883, Sensitivity: 0.1667, Specificity: 0.9033, G-Mean: 0.3880, Type I Error: 0.0967, Type II Error: 0.8333, F1 Score: 0.1973, AUROC: 0.5640
# Fold 5: Accuracy: 0.7925, Sensitivity: 0.2207, Specificity: 0.8983, G-Mean: 0.4453, Type I Error: 0.1017, Type II Error: 0.7793, F1 Score: 0.2494, AUROC: 0.6037
# Fold 6: Accuracy: 0.7890, Sensitivity: 0.1396, Specificity: 0.9092, G-Mean: 0.3563, Type I Error: 0.0908, Type II Error: 0.8604, F1 Score: 0.1713, AUROC: 0.5439
# Fold 7: Accuracy: 0.7989, Sensitivity: 0.1622, Specificity: 0.9167, G-Mean: 0.3855, Type I Error: 0.0833, Type II Error: 0.8378, F1 Score: 0.2011, AUROC: 0.5641
# Fold 8: Accuracy: 0.7975, Sensitivity: 0.2342, Specificity: 0.9017, G-Mean: 0.4596, Type I Error: 0.0983, Type II Error: 0.7658, F1 Score: 0.2653, AUROC: 0.6152
# Fold 9: Accuracy: 0.7961, Sensitivity: 0.2117, Specificity: 0.9042, G-Mean: 0.4375, Type I Error: 0.0958, Type II Error: 0.7883, F1 Score: 0.2448, AUROC: 0.6003
# Fold 10: Accuracy: 0.7771, Sensitivity: 0.1847, Specificity: 0.8867, G-Mean: 0.4047, Type I Error: 0.1133, Type II Error: 0.8153, F1 Score: 0.2055, AUROC: 0.5958
#
# ==== WminkowskiKNN ====
# Fold 1: Accuracy: 0.8067, Sensitivity: 0.1390, Specificity: 0.9308, G-Mean: 0.3597, Type I Error: 0.0692, Type II Error: 0.8610, F1 Score: 0.1840, AUROC: 0.5642
# Fold 2: Accuracy: 0.7941, Sensitivity: 0.1883, Specificity: 0.9067, G-Mean: 0.4132, Type I Error: 0.0933, Type II Error: 0.8117, F1 Score: 0.2228, AUROC: 0.5835
# Fold 3: Accuracy: 0.7982, Sensitivity: 0.1261, Specificity: 0.9225, G-Mean: 0.3411, Type I Error: 0.0775, Type II Error: 0.8739, F1 Score: 0.1633, AUROC: 0.5597
# Fold 4: Accuracy: 0.7982, Sensitivity: 0.1757, Specificity: 0.9133, G-Mean: 0.4006, Type I Error: 0.0867, Type II Error: 0.8243, F1 Score: 0.2137, AUROC: 0.5643
# Fold 5: Accuracy: 0.8003, Sensitivity: 0.1171, Specificity: 0.9267, G-Mean: 0.3294, Type I Error: 0.0733, Type II Error: 0.8829, F1 Score: 0.1548, AUROC: 0.5521
# Fold 6: Accuracy: 0.7940, Sensitivity: 0.1306, Specificity: 0.9167, G-Mean: 0.3460, Type I Error: 0.0833, Type II Error: 0.8694, F1 Score: 0.1652, AUROC: 0.5320
# Fold 7: Accuracy: 0.7876, Sensitivity: 0.1306, Specificity: 0.9092, G-Mean: 0.3446, Type I Error: 0.0908, Type II Error: 0.8694, F1 Score: 0.1611, AUROC: 0.5378
# Fold 8: Accuracy: 0.7989, Sensitivity: 0.1577, Specificity: 0.9175, G-Mean: 0.3803, Type I Error: 0.0825, Type II Error: 0.8423, F1 Score: 0.1966, AUROC: 0.6184
# Fold 9: Accuracy: 0.8150, Sensitivity: 0.1712, Specificity: 0.9342, G-Mean: 0.3999, Type I Error: 0.0658, Type II Error: 0.8288, F1 Score: 0.2242, AUROC: 0.5773
# Fold 10: Accuracy: 0.8136, Sensitivity: 0.1486, Specificity: 0.9367, G-Mean: 0.3731, Type I Error: 0.0633, Type II Error: 0.8514, F1 Score: 0.1994, AUROC: 0.5737
